# %%
pip install QuantStats
# Out:
# ...
#      |████████████████████████████████| 45 kB 2.2 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import quantstats as qs

MVvolRet = pd.read_csv("/Users/iliasrazig/Documents/mbf3/Mémoire/Algos/Valorisation du portefeuille optimisé Volatilité minimale.csv",header=[0], index_col=[0], parse_dates= True)
MVSR = pd.read_csv("/Users/iliasrazig/Documents/mbf3/Mémoire/Algos/Valorisation du portefeuille optimisé Ratio de Sharpe maximum.csv",header=[0], index_col=[0], parse_dates= True)
HRP = pd.read_csv("/Users/iliasrazig/Documents/mbf3/Mémoire/Allocations/Valorisation du portefeuille optimisé HRP mémoire Ilias.csv", header=[0], index_col=[0], parse_dates= True)
ML = pd.read_csv("/Users/iliasrazig/Documents/mbf3/Mémoire/Algos/Valorisation du portefeuille optimisé Ratio de Sharpe maximum avec ML.csv",header=[0], index_col=[0], parse_dates= True)

# %%
MVvolRet['0']
# Out:
# Date
# 2022-01-03    100.000000
# 2022-01-04    100.145491
# 2022-01-05    100.161537
# 2022-01-06     99.947406
# 2022-01-07    100.706291
#                  ...
# 2023-08-07     99.955387
# 2023-08-08     99.722557
# 2023-08-09     99.027982
# 2023-08-10     98.793252
# 2023-08-11     99.322715
# Name: 0, Length: 404, dtype: float64

# %%
qs.reports.full(MVvolRet['0'], MVSR['0'])
# Out:
# <h4>Performance Metrics</h4>
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               2022-01-04   2022-01-04
# End Period                 2023-07-31   2023-07-31
# Risk-Free Rate             0.0%         0.0%
# Time in Market             100.0%       100.0%
#
# Cumulative Return          -7.57%       -3.06%
# CAGR﹪                     -3.4%        -1.36%
#
# Sharpe                     -0.05        -0.03
# Prob. Sharpe Ratio         47.59%       48.32%
# Smart Sharpe               -0.05        -0.03
# Sortino                    -0.07        -0.05
# Smart Sortino              -0.07        -0.05
# Sortino/√2                 -0.05        -0.03
# Smart Sortino/√2           -0.05        -0.03
# Omega                      0.99         0.99
#
# Max Drawdown               -34.13%      -20.82%
# Longest DD Days            573          490
# Volatility (ann.)          27.31%       16.84%
# ...

# %%
qs.reports.full(HRP['0'], ML['0'])
# Out:
# <h4>Performance Metrics</h4>
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               2022-01-04   2022-01-04
# End Period                 2023-07-31   2023-07-31
# Risk-Free Rate             0.0%         0.0%
# Time in Market             100.0%       100.0%
#
# Cumulative Return          53.52%       -3.86%
# CAGR﹪                     20.74%       -1.72%
#
# Sharpe                     1.1          -0.04
# Prob. Sharpe Ratio         91.43%       48.12%
# Smart Sharpe               1.1          -0.04
# Sortino                    1.61         -0.05
# Smart Sortino              1.61         -0.05
# Sortino/√2                 1.14         -0.04
# Smart Sortino/√2           1.14         -0.04
# Omega                      0.99         0.99
#
# Max Drawdown               -17.97%      -23.56%
# Longest DD Days            134          573
# Volatility (ann.)          28.63%       19.0%
# ...
